# %%
import pandas as pd
import numpy as np
import random #delete after cross validation function is written

data = np.loadtxt('smallData.txt', dtype=np.float32)

# %%
def cross_validation(data, current_features, feature_index):
  return random.random()

# %%
current_features = []

for i in range (1,data.shape[1] - 1):
    print("On level", i, "of the search tree:")
    add_this_feature = None;
    max_accuracy = 0

    for k in range (1, data.shape[1] - 1):
      if k in current_features:
        continue
      print(" ... Consider adding feature", k)
      accuracy = cross_validation(data, current_features, k+1)
      #print(" Accuracy:", accuracy) #testing
      if accuracy > max_accuracy:
        max_accuracy = accuracy
        add_this_feature = k


    if (add_this_feature):
      current_features.append(add_this_feature)
      print(" *   We add feature", add_this_feature, "to the current set \n")
    else:
      print(" *   We do not add any feature to the current set \n")
# Out:
# On level 1 of the search tree:
#  ... Consider adding feature 1
#  ... Consider adding feature 2
#  ... Consider adding feature 3
#  ... Consider adding feature 4
#  ... Consider adding feature 5
#  *   We add feature 4 to the current set
#
# On level 2 of the search tree:
#  ... Consider adding feature 1
#  ... Consider adding feature 2
#  ... Consider adding feature 3
#  ... Consider adding feature 5
#  *   We add feature 1 to the current set
#
# On level 3 of the search tree:
#  ... Consider adding feature 2
#  ... Consider adding feature 3
#  ... Consider adding feature 5
#  *   We add feature 5 to the current set
#
# On level 4 of the search tree:
#  ... Consider adding feature 2
#  ... Consider adding feature 3
#  *   We add feature 2 to the current set
#
# On level 5 of the search tree:
#  ... Consider adding feature 3
#  *   We add feature 3 to the current set
